# %%
from recap_v2 import *

# %%
test = stat_json('json')

# %%
test.pourc_rep()
# Out:
# *****Hebdomadaire
# bcc08 : 0.40476190476190477
# bcm03 : 0.35714285714285715
# bda04 : 0.47619047619047616
# bmf02 : 0.38095238095238093
# bmm01 : 0.40476190476190477
# bss05 : 0.35714285714285715
# cca01 : 0.35714285714285715
# ccm03 : 0.42857142857142855
# cda10 : 0.47619047619047616
# ced06 : 0.3333333333333333
# cjl09 : 0.40476190476190477
# cll02 : 0.40476190476190477
# ldd19 : 0.4523809523809524
# ldi16 : 0.5238095238095238
# lke15 : 0.35714285714285715
# lmi13 : 0.4523809523809524
# lrb12 : 0.42857142857142855
# mcl41 : 0.21428571428571427
# mcn53 : 0.40476190476190477
# mds47 : 0.38095238095238093
# mfc55 : 0.38095238095238093
# mim42 : 0.42857142857142855
# mlm43 : 0.40476190476190477
# mmc40 : 0.40476190476190477
# mmg52 : 0.40476190476190477
# mml45 : 0.40476190476190477
# mnr36 : 0.5
# mpm44 : 0.40476190476190477
# mpn58 : 0.4523809523809524
# mra54 : 0.47619047619047616
# mrp34 : 0.40476190476190477
# msc39 : 0.42857142857142855
# msl49 : 0.47619047619047616
# ...

# %%
test.ids_total()
# Out:
# *****Hebdomadaire
# q2_intens_idees_suicid : 1.3714285714285714
# q3_intensite_tuer : 0.9714285714285714
# idees_suicidaires_moyen : 4.542857142857143
# intens_moy_tuer : 2.1714285714285713
#
# *****Spontané
# intensite_idee_suicide : 2.217391304347826
# intensite_intention_suicide : 1.6521739130434783
# q21_me_faire_mal_metuer : 1.5217391304347827
#
# *****Mensuel
#
# *****Spontané_1
# intensite_idee_suicide : 1.6666666666666667
# intensite_intention_suicide : 0.6666666666666666
# q21_me_faire_mal_metuer : 0.6666666666666666
#
# *****Hebdomadaire_1
# q2_intens_idees_suicid : 1.6
# q3_intensite_tuer : 1.1666666666666667
# idees_suicidaires_moyen : 3.566666666666667
# intens_moy_tuer : 2.2666666666666666
#
# *****Spontané_2
# intensite_idee_suicide : 2.1
# intensite_intention_suicide : 1.4
# q21_me_faire_mal_metuer : 2.3
#
# *****Hebdomadaire_2
# q2_intens_idees_suicid : 2.1923076923076925
# q3_intensite_tuer : 1.2692307692307692
# idees_suicidaires_moyen : 2.3846153846153846
# ...
