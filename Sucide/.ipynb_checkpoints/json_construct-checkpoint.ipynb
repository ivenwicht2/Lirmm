# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def construct(data,question,root,user):
    print(root)
    if root == '':
        root =  data['quests'][0]["dataquestionnaire"]
    else : 
        root = data
    if user == '':
        try : 
            user = data['logs'][0]['IDuser']

        except :
            user = "unknow"
        question[user] = {}


    for element in root:
        typeQ = element['answerType']

        if typeQ not in question[user] :
            question[user][typeQ] = {}

        question[user][typeQ][element['code']] = {}

        if typeQ == "Range":
            if 'sousquest' in element['options'] :
                question[user][typeQ][element['code']] = {
                    'value' : element['value'],
                    'subtitle':element['subtitle'],
                    'subquestions':{},
                    'answered':element['answered'],
                    'root' : root}  

                for subquestion in element['options']['sousquest'] :
                    construct([subquestion],question,element['code'],user)

            else :
                question[user][typeQ][element['code']] = {
                    'value' : element['value'],
                    'min-max' : [element['options']['min'] ,element['options']['max']],
                    'root':root}            


        if typeQ == "Radio" :
            for subquestion in element['questionOptions'] :
                question[user][typeQ][element['code']][subquestion['text']] = { 
                    "checked": subquestion['checked'] ,
                    "value": subquestion['value'],
                    "root": root}

        if typeQ == 'Checkbox' :
            for subquestion in element['questionOptions'] :
                question[user][typeQ][element['code']][subquestion['text']] = { 
                    "checked": subquestion['checked'] ,
                    "value": subquestion['value'],
                    "root": root}
       
        if typeQ == 'Text' :
            question[user][typeQ][element['code']] = {
                'value' : element["value"],
                'root' : root
                }

        if typeQ == 'YesNo':
            if 'sousquest' in element['options'] :
                question[user][typeQ][element['code']] = {
                    'value' : element['checked'],
                    'subquestion_name' : {element['options']['sousquest'][0]['code']},
                    'subquestions':{},
                    'subtitle' :element['options']['sousquest'][0]['subtitle'],
                    'root' : root }
                
                for subquestion in element['options']['sousquest'] :
                    construct([subquestion],question,element['code'],user)

            else :
                question[user][typeQ][element['code']] = {
                    'value' : element['checked'],
                    'root' : root }

        if typeQ == 'Contact':
            question[user][typeQ][element['code']] = {
                'subtitle' : element['subtitle'],
                'value' : element['value'],
                'root' : root  }

    return question

# %%
files = os.listdir("json")
question = {}
for file in files :
    with open("json/{}".format(file), 'r',encoding='utf8') as f:
        datastore = json.load(f)
        if "quests" in datastore :
                if datastore["quests"] != []:
                    question = construct(datastore,question,'','')
"""with open('reconstruct-json.json', 'w') as outfile:
    json.dump(question, outfile)"""
# Out:
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# question_13
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# question_13
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# question_13
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# question_13
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# question_13
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# question_13
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# question_13
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# question_13
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# question_13
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# prestations_sociales
# enfants
# enfants
# beaux_enfants
# beaux_enfants
# maladie_psychiatrique_passe
# maladie_psychiatrique_famille
# tentatives_suicide
# tentatives_suicide_famille
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# q1_douleur_psy
# q1_douleur_psy
# douleur_morale_moyen
# douleur_morale_moyen
# urgences_psychiatriques
# evenement_negatif
# comportements_suicidaires
# comportements_suicidaires
# comportements_suicidaires_facteurs_declenchants
# comportements_suicidaires
# comportements_suicidaires_aide
# satisfaction_relations_familiales_sans_contact
# satisfaction_relations_sans_couple
# satisfaction_relations_amicales_sans_contact
# satisfaction_relations_professionnelles_sans_contact
# conflits
# conflits
# conflits
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
#
# matin_bien_dormi
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# q5_emma_douleur_morale
# evenement_relationnel
# evenement_relationnel
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# q18_evenement_impact
# soir_douleurs_physiques
# soir_activite_importante
# soir_faire_du_mal
# soir_conflits
# soir_faire_souhait
# soir_traitement
# "with open('reconstruct-json.json', 'w') as outfile:\n    json.dump(question, outfile)"

# %%
question.keys()
# Out:
# dict_keys(['bcc08', 'bcm03', 'bda04', 'bmf02', 'bmm01', 'bss05', 'cbc08', 'cca01', 'ccm03', 'ccm11', 'cda10', 'ced06', 'cjl09', 'cll02', 'crs05', 'lam07', 'lba11', 'lbk01', 'lcp06', 'unknow', 'ldd19', 'ldi16', 'lej14', 'lgf18', 'lhn11', 'lke15', 'lmi13', 'lpj09', 'lrb12', 'lwd02', 'mam27', 'mbe25', 'mca51', 'mcc57', 'mcd13', 'mcf14', 'mcl41', 'mcn02', 'mcn53', 'mcy15', 'mda28', 'mdp03', 'mds47', 'mea22', 'mef06', 'mfc55', 'mgc21', 'mgf18', 'mgl33', 'mhe20', 'mhm23', 'mim42', 'mka30', 'mla26', 'mlf16', 'mlj09', 'mlm43', 'mlr10', 'mlr17', 'mls35', 'mlv05', 'mmc40', 'mme04', 'mmg52', 'mmk24', 'mml45', 'mmm12', 'mmo32', 'mmz01', 'mnd28', 'mnr36', 'mpc11', 'mpm38', 'mpm44', 'mpm50', 'mpn58', 'mpv08', 'mra19', 'mra54', 'mrp34', 'msc39', 'msl49', 'msn46', 'mty60', 'mwa48', 'myg07'])

# %%
question['bcc08']
# Out:
# e',
#      'questionOptions': [],
#      'datefinished': 'Fri Dec 27 2019 14:31:24 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {'max': 10,
#       'maxLabel': 'Extrême',
#       'minLabel': 'Nul',
#       'min': 0}},
#     {'code': 'q10_emma_faire',
#      'subtitle': "J'étais en train de :",
#      'title': "Qu'étiez-vous en train de faire ?",
#      'answered': 'true',
#      'answerType': 'Checkbox',
#      'questionOptions': [{'text': "m'occuper pour ne pas penser",
#        'checked': 'false',
#        'value': 'm_occuper'},
#       {'text': 'ne rien faire', 'checked': 'false', 'value': 'rien_faire'},
#       {'text': 'ruminer, essayer de penser à autre chose',
#        'checked': 'false',
#        'value': 'ruminer'},
#       {'text': 'faire une activité qui me plaît ou qui a du sens pour moi',
#        'checked': 'false',
#        'value': 'activite'},
#       {'text': 'travailler', 'checked': 'false', 'value': 'travailler'},
#       {'text': 'faire des tâches ménagères',
#        'checked': 'false',
#        'value': 'taches_menageres'},
#       {'text': 'autre', 'checked': True, 'value': 'autre'}],
#      'datefinished': 'Fri Dec 27 2019 14:31:29 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {}},
#     {'code': 'lieu',
#      'subtitle': '',
#      'title': 'Où êtes-vous en ce moment ?',
#      'selItem': 'deplacement',
#      'answered': 'true',
#      'answerType': 'Radio',
#      'questionOptions': [{'text': 'chez moi',
#        'checked': 'false',
#        'value': 'chez_moi'},
#       {'text': 'chez mon/ma partenaire',
#        'checked': 'false',
#        'value': 'chez_partenaire'},
#       {'text': 'chez mes parents ou ma famille',
#        'checked': 'false',
#        'value': 'famille'},
#       {'text': 'chez mes amis', 'checked': 'false', 'value': 'amis'},
#       {'text': 'à mon travail', 'checked': 'false', 'value': 'travail'},
#       {'text': 'en classe', 'checked': 'false', 'value': 'classe'},
#       {'text': 'en déplacement (transports en communs...)',
#        'checked': 'false',
#        'value': 'deplacement'},
#       {'text': "à l'intérieur (maison...)",
#        'checked': 'false',
#        'value': 'interieur'},
#       {'text': "à l'extérieur (jardin...)",
#        'checked': 'false',
#        'value': 'exterieur'},
#       {'text': 'autre', 'checked': 'false', 'value': 'autre'}],
#      'datefinished': 'Fri Dec 27 2019 14:31:45 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {}},
#     {'code': 'entourage',
#      'subtitle': '',
#      'title': 'Qui est avec vous <strong>maintenant</strong> ?',
#      'answered': 'true',
#      'answerType': 'Checkbox',
#      'questionOptions': [{'text': 'personne, je suis seul(e)',
#        'checked': 'false',
#        'value': 'personne'},
#       {'text': 'famille', 'checked': 'false', 'value': 'famille'},
#       {'text': 'amis', 'checked': 'false', 'value': 'amis'},
#       {'text': 'partenaire/petit(e) ami(e)',
#        'checked': 'false',
#        'value': 'partenaire'},
#       {'text': 'collègue(s) de travail',
#        'checked': 'false',
#        'value': 'collegues'},
#       {'text': 'étudiants', 'checked': 'false', 'value': 'etudiants'},
#       {'text': 'des inconnus', 'checked': True, 'value': 'inconnus'},
#       {'text': 'un ou des animaux (chien, ...)',
#        'checked': 'false',
#        'value': 'animaux'},
#       {'text': 'autre', 'checked': 'false', 'value': 'autre'}],
#      'datefinished': 'Fri Dec 27 2019 14:31:59 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {}},
#     {'code': 'evenement',
#      'subtitle': "Quel a été l'événement ou l'expérience qui vous a le plus affecté(e) depuis ce matin ?",
#      'title': '',
#      'value': '',
#      'answered': 'notfreq',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'cond': 'first'}},
#     {'code': 'evenement',
#      'subtitle': "Quel a été l'événement ou l'expérience qui vous a le plus affecté(e)depuis la dernière fois que vous avez répondu au questionnaire ?",
#      'title': '',
#      'value': 'Dimitri',
#      'answered': 'true',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'Fri Dec 27 2019 14:32:16 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {'condnot': 'first'}},
#     {'code': 'evenement_relationnel',
#      'subtitle': 'Cet événement était-il relationnel ?',
#      'title': '',
#      'answered': 'true',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': True,
#      'datefinished': 'Fri Dec 27 2019 14:32:40 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {'sousquest': [{'code': 'evenement_contact',
#         'subtitle': 'Qui cela a t-il impliqué ?',
#         'title': '',
#         'value': 'Dimitri ❤️',
#         'answered': 'false',
#         'answerType': 'Contact',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {}},
#        {'code': 'evenement_heure',
#         'subtitle': "À quel moment cela s'est-il passé ? ",
#         'title': '',
#         'value': '00:00',
#         'answered': 'false',
#         'answerType': 'Time',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'true'}},
#     {'code': 'q18_evenement_impact',
#      'subtitle': '',
#      'title': 'Quel impact cet événement a-t-il eu sur vous ?',
#      'value': 3,
#      'answered': 'true',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'Fri Dec 27 2019 14:32:53 GMT+0100 (heure normale d’Europe centrale)',
#      'options': {'min': -5,
#       'max': 5,
#       'sousquest': [{'code': 'q19_evenement_impact_envie',
#         'subtitle': "Cela m'a donné envie de :",
#         'title': '',
#         'answered': 'false',
#         'answerType': 'Checkbox',
#         'questionOptions': [{'text': 'faire quelque chose de plaisant pour moi',
#           'checked': 'false',
#           'value': 'plaisant'},
#          {'text': 'me faire du mal',
#           'checked': 'false',
#           'value': 'me_faire_du_mal'},
#          {'text': "boire de l'alcool",
#           'checked': 'false',
#           'value': 'boire_de_lalcool'},
#          {'text': 'prendre des toxiques',
#           'checked': 'false',
#           'value': 'prendre_des_toxiques'},
#          {'text': 'fumer du cannabis',
#           'checked': 'false',
#           'value': 'fumer_du_cannabis'},
#          {'text': 'prendre des calmants',
#           'checked': 'false',
#           'value': 'prendre_des_calmants'},
#          {'text': 'me remplir de nourriture ',
#           'checked': 'false',
#           'value': 'me_remplir_de_nourriture '}],
#         'datefinished': 'nan'},
#        {'code': 'q21_me_faire_mal_metuer',
#         'subtitle': 'me tuer',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10, 'maxLabel': '', 'minLabel': '', 'min': 0}},
#        {'code': 'besoins_imperieux_2',
#         'subtitle': 'me couper/me scarifier',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10, 'maxLabel': '', 'minLabel': '', 'min': 0}},
#        {'code': 'besoins_imperieux_3',
#         'subtitle': 'me brûler',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10, 'maxLabel': '', 'minLabel': '', 'min': 0}},
#        {'code': 'besoins_imperieux_4',
#         'subtitle': 'me frapper',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10, 'maxLabel': '', 'minLabel': '', 'min': 0}},
#        {'code': 'besoins_imperieux_5',
#         'subtitle': 'autre',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10, 'maxLabel': '', 'minLabel': '', 'min': 0}}],
#       'maxLabel': 'extrêmement positif',
#       'minLabel': 'extrêmement négatif',
#       'if': '0'}},
#     {'code': 'pensees_interpretation',
#      'subtitle': '',
#      'title': 'Quelles sont vos interprétations de cet événement ? Que vous dites-vous sur cette situation ?',
#      'value': '',
#      'answered': 'ignored',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {}},
#     {'code': 'jour_qualite_appetit',
#      'subtitle': "Comment est votre appétit aujourd'hui\xa0?",
#      'title': '',
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': 'Très mauvaise',
#       'maxLabel': 'Excellente',
#       'min': 0}},
#     {'code': 'soir_douleurs_physiques',
#      'subtitle': "Avez-vous eu des douleurs physiques aujourd'hui ?",
#      'title': '',
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'min': 0,
#       'max': 10,
#       'sousquest': [{'code': 'soir_douleurs_physiques_tolerance',
#         'subtitle': 'À quel point avez-vous trouvé cette douleur tolérable ?',
#         'title': '',
#         'value': 0,
#         'answered': 'false',
#         'answerType': 'Range',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {'max': 10,
#          'maxLabel': 'Tout à fait tolérable',
#          'minLabel': 'Pas du tout tolérable',
#          'min': 0}}],
#       'cond': 'last',
#       'minLabel': 'Pas du tout',
#       'maxLabel': 'Beaucoup',
#       'if': '5'}},
#     {'code': 'ressentis_sentiments',
#      'subtitle': 'Que ressentez-vous en vous en ce moment ?',
#      'title': '',
#      'answered': 'notfreq',
#      'answerType': 'Checkbox',
#      'questionOptions': [{'text': 'je suis un fardeau pour les autres',
#        'checked': 'false',
#        'value': 'fardeau'},
#       {'text': 'je suis sans espoir',
#        'checked': 'false',
#        'value': 'sans_espoir'},
#       {'text': "j'ai échoué", 'checked': 'false', 'value': 'echec'},
#       {'text': 'colère/irritabilité ', 'checked': 'false', 'value': 'col'},
#       {'text': 'tristesse', 'checked': 'false', 'value': 'trit'},
#       {'text': 'honte/humiliation', 'checked': 'false', 'value': 'honte'},
#       {'text': 'peur/Anxiété ', 'checked': 'false', 'value': 'peur'},
#       {'text': 'dégoût', 'checked': 'false', 'value': 'deg'},
#       {'text': 'joie/plaisir', 'checked': 'false', 'value': 'joie'},
#       {'text': 'culpabilité', 'checked': 'false', 'value': 'culp'},
#       {'text': 'intérêt/curiosité', 'checked': 'false', 'value': 'int'},
#       {'text': 'surprise', 'checked': 'false', 'value': 'echec'},
#       {'text': 'ennui/vide', 'checked': 'false', 'value': 'ennui'},
#       {'text': 'sérénité', 'checked': 'false', 'value': 'ser'},
#       {'text': 'espoir', 'checked': 'false', 'value': 'espoir'},
#       {'text': 'fierté', 'checked': 'false', 'value': 'fiert'},
#       {'text': 'amour', 'checked': 'false', 'value': 'amour'}],
#      'datefinished': 'nan',
#      'options': {'cond': 'last'}},
#     {'code': 'soir_activite_importante',
#      'subtitle': "Aujourd'hui, est-ce que avez fait quelque chose d'important pour vous ?",
#      'title': '',
#      'answered': 'notfreq',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {'cond': 'last',
#       'sousquest': [{'code': 'soir_activites',
#         'subtitle': '',
#         'title': '',
#         'answered': 'false',
#         'answerType': 'Checkbox',
#         'questionOptions': [{'text': "j'ai fait du sport",
#           'checked': 'false',
#           'value': 'sport'},
#          {'text': "j'ai vu ma famille / mes amis",
#           'checked': 'false',
#           'value': 'famille/amis'},
#          {'text': 'je me suis promené(e)',
#           'checked': 'false',
#           'value': 'promenade'},
#          {'text': "j'ai lu", 'checked': 'false', 'value': 'lecture'},
#          {'text': "j'ai regardé un film", 'checked': 'false', 'value': 'film'},
#          {'text': "j'ai eu des relations sexuelles",
#           'checked': 'false',
#           'value': 'relations_sexuelles'},
#          {'text': "j'ai joué", 'checked': 'false', 'value': 'jeu'},
#          {'text': 'autre', 'checked': 'false', 'value': 'autre'}],
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'true'}},
#     {'code': 'soir_faire_du_mal',
#      'subtitle': "Aujourd'hui, est-ce que vous vous êtes fait du mal ?",
#      'title': '',
#      'answered': 'notfreq',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {'cond': 'last',
#       'sousquest': [{'code': 'soir_faire_du_mal_comment',
#         'subtitle': '',
#         'title': '',
#         'answered': 'false',
#         'answerType': 'Checkbox',
#         'questionOptions': [{'text': 'je me suis scarifié(e) ou brûlé(e)',
#           'checked': 'false',
#           'value': 'scarifie_brule'},
#          {'text': "j'ai essayé de me tuer",
#           'checked': 'false',
#           'value': 'tentative_tuer'},
#          {'text': "j'ai bu une grande quantité d'alcool",
#           'checked': 'false',
#           'value': 'alcool'},
#          {'text': 'je me suis rempli(e) de nourriture',
#           'checked': 'false',
#           'value': 'nourriture'},
#          {'text': "j'ai pris des toxiques",
#           'checked': 'false',
#           'value': 'toxiques'},
#          {'text': "j'ai fumé du cannabis",
#           'checked': 'false',
#           'value': 'cannabis'},
#          {'text': "j'ai pris des calmants",
#           'checked': 'false',
#           'value': 'calmants'},
#          {'text': 'autre', 'checked': 'false', 'value': 'autre'}],
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'true'}},
#     {'code': 'soir_conflits',
#      'subtitle': "Avez-vous vécu des conflits aujourd'hui ?",
#      'title': '',
#      'answered': 'notfreq',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {'cond': 'last',
#       'sousquest': [{'code': 'soir_conflits_type',
#         'subtitle': '',
#         'title': '',
#         'answered': 'false',
#         'answerType': 'Checkbox',
#         'questionOptions': [{'text': 'familiaux',
#           'checked': 'false',
#           'value': 'familiaux'},
#          {'text': 'amicaux', 'checked': 'false', 'value': 'amicaux'},
#          {'text': 'professionnels',
#           'checked': 'false',
#           'value': 'professionnels'}],
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'true'}},
#     {'code': 'soir_conflits_reaction',
#      'subtitle': 'Comment avez-vous réagi ?',
#      'title': '',
#      'value': '',
#      'answered': 'notfreq',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'cond': 'last'}},
#     {'code': 'soir_bien',
#      'subtitle': 'Qu’est ce que vous avez fait de bien aujourd’hui ?',
#      'title': '',
#      'value': '',
#      'answered': 'notfreq',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'cond': 'last'}},
#     {'code': 'soir_ressenti',
#      'subtitle': 'Comment vous sentez-vous ?',
#      'title': '',
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': 'Très mal',
#       'maxLabel': 'Très bien',
#       'min': 0}},
#     {'code': 'soir_faire_souhait',
#      'subtitle': 'Avez-vous pu faire ce que vous souhaitiez aujourd’hui ?',
#      'title': '',
#      'answered': 'notfreq',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {'cond': 'last',
#       'sousquest': [{'code': 'soir_faire_souhait_pourquoi',
#         'subtitle': 'Pourquoi selon vous ?',
#         'title': '',
#         'value': '',
#         'answered': 'false',
#         'answerType': 'Text',
#         'questionOptions': [],
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'false'}},
#     {'code': 'soir_traitement',
#      'subtitle': "Si vous avez des traitements, les avez-vous bien pris aujourd'hui ?",
#      'title': '',
#      'graph': True,
#      'required': True,
#      'answered': 'notfreq',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {'cond': 'last',
#       'sousquest': [{'code': 'soir_traitement_benefique',
#         'subtitle': "Est-ce que vous avez l'impression que ça vous a été bénéfique ?",
#         'title': '',
#         'answered': 'false',
#         'answerType': 'YesNo',
#         'questionOptions': [],
#         'checked': False,
#         'datefinished': 'nan',
#         'options': {}}],
#       'if': 'true'}},
#     {'code': 'soir_bonne_journee',
#      'subtitle': 'Avez-vous passé une bonne journée ?',
#      'title': '',
#      'graph': True,
#      'required': True,
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': 'Très mauvaise',
#       'maxLabel': 'Excellente',
#       'min': 0}},
#     {'code': 'autrui_connect',
#      'subtitle': "À combien vous êtes-vous senti connecté avec autrui aujourd'hui ?",
#      'title': '',
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': '',
#       'maxLabel': '',
#       'min': 0}},
#     {'code': 'soir_humeur',
#      'subtitle': 'Évaluez votre humeur de la journée',
#      'title': '',
#      'graph': True,
#      'required': True,
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': 'Extrêment déprimée',
#       'maxLabel': 'Normale',
#       'min': -10}},
#     {'code': 'soir_journee_vs_prevu',
#      'subtitle': "Votre journée s'est-elle déroulée mieux ou moins bien que prévu ?",
#      'title': '',
#      'value': 0,
#      'answered': 'notfreq',
#      'answerType': 'Range',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'max': 10,
#       'cond': 'last',
#       'minLabel': 'Moins bien',
#       'maxLabel': 'Mieux',
#       'min': 0}},
#     {'code': 'soir_choses_positives',
#      'subtitle': "Quelles ont été les choses positives aujourd'hui ?",
#      'title': '',
#      'value': '',
#      'answered': 'notfreq',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'cond': 'last'}},
#     {'code': 'soir_liste_mieux_que_prevu',
#      'subtitle': 'Listez les choses que votre mental vous avait prédit qui se passeraient mal, et qui se sont finalement mieux passées que prévu.',
#      'title': '',
#      'value': '',
#      'answered': 'notfreq',
#      'answerType': 'Text',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {'cond': 'last'}}]},
#   'soir_traitement_benefique': {'value': False,
#    'root': [{'code': 'soir_traitement_benefique',
#      'subtitle': "Est-ce que vous avez l'impression que ça vous a été bénéfique ?",
#      'title': '',
#      'answered': 'false',
#      'answerType': 'YesNo',
#      'questionOptions': [],
#      'checked': False,
#      'datefinished': 'nan',
#      'options': {}}]}},
#  'Contact': {'evenement_contact': {'subtitle': 'Qui cela a t-il impliqué ?',
#    'value': 'Dimitri ❤️',
#    'root': [{'code': 'evenement_contact',
#      'subtitle': 'Qui cela a t-il impliqué ?',
#      'title': '',
#      'value': 'Dimitri ❤️',
#      'answered': 'false',
#      'answerType': 'Contact',
#      'questionOptions': [],
#      'datefinished': 'nan',
#      'options': {}}]}},
#  'Time': {'evenement_heure': {}}}

# %%
Nnumeric = ['evenement','pensees_interpretation','soir_conflits_reaction','soir_bien','soir_choses_positives','soir_liste_mieux_que_prevu','heures_personnes_importantes','heures_loisirs','sens','bon_moments','semaine_prochaine','question_24','age']
c = {'valeur moyenne' : 'red','Particiation en pourcentage' :'blue'}
for i, key in enumerate(question.keys()):
    if key not in  Nnumeric :
        element = question[key] 
        x = np.mean(element)
        x2 = len(element)/len(files)
        plt.figure(i)
        plt.bar([0], [x],color=c['valeur moyenne'])
        plt.bar([1], [x2],color=c['Particiation en pourcentage'])
        plt.title(key)
        plt.legend(c)

# %%
plt.bar([0,1], [x,x2])

# %%
type([])
